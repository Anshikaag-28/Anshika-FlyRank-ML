# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshikaag-28/Anshika-FlyRank-ML/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Anshikaag-28/Anshika-FlyRank-ML/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
# I am choosing **Lane 2: Refresh / Content Opportunity Scoring**. I want to investigate which content pages should be reviewed first for refresh, expansion, protection, pruning, or monitoring using observable search and content signals. I chose this lane because the starter dataset contains useful signals such as impressions, CTR, average position, content age, freshness, word count, sessions, and engagement. A ranked review queue could help a content team use limited review time more effectively. This also builds naturally on the starter notebooks, where simple rules and machine-learning models were used to rank pages for review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# ### Research question
#
# **Which pages should be reviewed first for refresh, expansion, protection, pruning, or monitoring based on observable search and content signals?**
#
# ### Decision
#
# The work will improve the decision of **which content pages a limited review team should prioritize first**.
#
# ### Action
#
# A reviewer can inspect the highest-ranked pages and decide whether to refresh, expand, protect, prune, or monitor them based on the available evidence and reason codes.
#
# ### Cost of a wrong recommendation
#
# A false positive could waste limited review and editing time on a page that does not need attention. A false negative could cause an important page or improvement opportunity to be missed. Therefore, ranking quality and review capacity are more relevant to this problem than simply maximizing overall accuracy.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !git clone https://github.com/Anshikaag-28/Anshika-FlyRank-ML.git
# Out:
# Cloning into 'Anshika-FlyRank-ML'...
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 122 (delta 34), reused 98 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (122/122), 1.87 MiB | 11.04 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
# %cd Anshika-FlyRank-ML
# Out:
# /content/Anshika-FlyRank-ML/Anshika-FlyRank-ML/Anshika-FlyRank-ML

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

declining_rate = (
    df["trend_direction"].str.lower().eq("down").mean()
)

print("Number of pages:", len(df))
print("Median impressions_90d:", round(df["impressions_90d"].median(), 1))
print("Declining rate:", round(declining_rate * 100, 1), "%")
# Out:
# Number of pages: 30000
# Median impressions_90d: 731.0
# Declining rate: 54.2 %

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# ### What I can claim
#
# I can report measured patterns and associations between observable search/content signals and page performance. I can test whether a ranking approach can help prioritize pages for human review under a defined validation setup.
#
# ### What I cannot claim
#
# I cannot claim that refreshing a recommended page will definitely cause its traffic or performance to recover. The data is observational and does not provide a causal experiment.
#
# I also cannot claim that the model predicts or proves Google's ranking algorithm. The results should be described as observed, directional, and useful for decision support.
#
# The starter-model results are also not a guarantee of final performance. Any larger-warehouse result will need to be validated separately.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
